# %% [markdown]
# # Publications markdown generator for academicpages
#
# Takes a set of bibtex of publications and converts them for use with [academicpages.github.io](academicpages.github.io). This is an interactive Jupyter notebook ([see more info here](http://jupyter-notebook-beginner-guide.readthedocs.io/en/latest/what_is_jupyter.html)).
#
# The core python code is also in `pubsFromBibs.py`.
# Run either from the `markdown_generator` folder after replacing updating the publist dictionary with:
# * bib file names
# * specific venue keys based on your bib file preferences
# * any specific pre-text for specific files
# * Collection Name (future feature)
#
# TODO: Make this work with other databases of citations,
# TODO: Merge this with the existing TSV parsing solution

# %%
from pybtex.database import parse_file

bib_data = parse_file('mypaper.bib', bib_format='bibtex')
print('总条目数:', len(bib_data.entries))

for key, entry in bib_data.entries.items():
    authors = entry.persons.get('author')
    if authors is None:
        print(f'⚠️ {key}: 没有 author 字段')
    elif len(authors) == 0:
        print(f'⚠️ {key}: author 字段为空')
    else:
        for idx, author in enumerate(authors):
            if not author.last_names:
                print(f'⚠️ {key}: 第{idx+1}个作者缺少姓氏')
                break
            if not author.first_names:
                print(f'⚠️ {key}: 第{idx+1}个作者缺少名字')
                break
# Out:
# 总条目数: 292

# %%
from pybtex.database.input import bibtex
import pybtex.database.input.bibtex 
from time import strptime
import string
import html
import os
import re

# %%
#todo: incorporate different collection types rather than a catch all publications, requires other changes to template
publist = {
    "proceeding": {
        "file" : "mypaper.bib",
        "venuekey": "booktitle",
        "venue-pretext": "In the proceedings of ",
        "collection" : {"name":"publications",
                        "permalink":"/publication/"}
        
    },
    "journal":{
        "file": "mypaper.bib",
        "venuekey" : "journal",
        "venue-pretext" : "",
        "collection" : {"name":"publications",
                        "permalink":"/publication/"}
    } 
}

# %%
html_escape_table = {
    "&": "&amp;",
    '"': "&quot;",
    "'": "&apos;"
    }

def html_escape(text):
    """Produce entities within text."""
    return "".join(html_escape_table.get(c,c) for c in text)

# %%
for pubsource in publist:
    parser = bibtex.Parser()
    bibdata = parser.parse_file(publist[pubsource]["file"])

    #loop through the individual references in a given bibtex file
    for bib_id in bibdata.entries:
        #reset default date
        pub_year = "1900"
        pub_month = "01"
        pub_day = "01"
        
        b = bibdata.entries[bib_id].fields
        
        try:
            pub_year = f'{b["year"]}'

            #todo: this hack for month and day needs some cleanup
            if "month" in b.keys(): 
                if(len(b["month"])<3):
                    pub_month = "0"+b["month"]
                    pub_month = pub_month[-2:]
                elif(b["month"] not in range(12)):
                    tmnth = strptime(b["month"][:3],'%b').tm_mon   
                    pub_month = "{:02d}".format(tmnth) 
                else:
                    pub_month = str(b["month"])
            if "day" in b.keys(): 
                pub_day = str(b["day"])

                
            pub_date = pub_year+"-"+pub_month+"-"+pub_day
            
            #strip out {} as needed (some bibtex entries that maintain formatting)
            clean_title = b["title"].replace("{", "").replace("}","").replace("\\","").replace(" ","-")    

            url_slug = re.sub("\\[.*\\]|[^a-zA-Z0-9_-]", "", clean_title)
            url_slug = url_slug.replace("--","-")

            md_filename = (str(pub_date) + "-" + url_slug + ".md").replace("--","-")
            html_filename = (str(pub_date) + "-" + url_slug).replace("--","-")

            #Build Citation from text
            citation = ""

            #citation authors - todo - add highlighting for primary author?
            for author in bibdata.entries[bib_id].persons["author"]:
                citation = citation+" "+author.first_names[0]+" "+author.last_names[0]+", "

            #citation title
            citation = citation + "\"" + html_escape(b["title"].replace("{", "").replace("}","").replace("\\","")) + ".\""

            #add venue logic depending on citation type
            venue = publist[pubsource]["venue-pretext"]+b[publist[pubsource]["venuekey"]].replace("{", "").replace("}","").replace("\\","")

            citation = citation + " " + html_escape(venue)
            citation = citation + ", " + pub_year + "."

            
            ## YAML variables
            md = "---\ntitle: \""   + html_escape(b["title"].replace("{", "").replace("}","").replace("\\","")) + '"\n'
            
            md += """collection: """ +  publist[pubsource]["collection"]["name"]
            # ---------- 添加以下代码 ----------
            # 根据条目类型设置 category
            if 'journal' in b.keys():
                category = 'manuscripts'
            elif 'booktitle' in b.keys():
                category = 'conferences'
            else:
                category = 'misc'
            md += f"\ncategory: {category}"
            # ---------- 添加结束 ----------
            md += """\npermalink: """ + publist[pubsource]["collection"]["permalink"]  + html_filename
            
            note = False
            if "note" in b.keys():
                if len(str(b["note"])) > 5:
                    md += "\nexcerpt: '" + html_escape(b["note"]) + "'"
                    note = True

            md += "\ndate: " + str(pub_date) 

            md += "\nvenue: '" + html_escape(venue) + "'"
            
            url = False
            if "url" in b.keys():
                if len(str(b["url"])) > 5:
                    md += "\npaperurl: '" + b["url"] + "'"
                    url = True

            md += "\ncitation: '" + html_escape(citation) + "'"

            md += "\n---"

            
            ## Markdown description for individual page
            if note:
                md += "\n" + html_escape(b["note"]) + "\n"

            if url:
                md += "\n[Access paper here](" + b["url"] + "){:target=\"_blank\"}\n" 
            else:
                md += "\nUse [Google Scholar](https://scholar.google.com/scholar?q="+html.escape(clean_title.replace("-","+"))+"){:target=\"_blank\"} for full citation"

            md_filename = os.path.basename(md_filename)

            with open("../_publications/" + md_filename, 'w', encoding="utf-8") as f:
                f.write(md)
            print(f'SUCESSFULLY PARSED {bib_id}: \"', b["title"][:60],"..."*(len(b['title'])>60),"\"")
        # field may not exist for a reference
        except KeyError as e:
            print(f'WARNING Missing Expected Field {e} from entry {bib_id}: \"', b["title"][:30],"..."*(len(b['title'])>30),"\"")
            continue
# Out:
# SUCESSFULLY PARSED song2008normalized: " A normalized LLR soft information demapping method in DTMB s ... "
# SUCESSFULLY PARSED song2014clustering: " Clustering based online learning in recommender systems: A b ... "
# WARNING Missing Expected Field 'booktitle' from entry song2016online: " Online Learning in Large-scale ... "
# SUCESSFULLY PARSED xu2014context: " Context-driven online learning for activity classification i ... "
# WARNING Missing Expected Field 'booktitle' from entry song2014demand: " Demand side management in smar ... "
# SUCESSFULLY PARSED song2014non: " Non-stationary demand side management method for smart grids  "
# WARNING Missing Expected Field 'booktitle' from entry xu2016personalized: " Personalized active learning f ... "
# WARNING Missing Expected Field 'booktitle' from entry song2015using: " Using contextual learning to i ... "
# WARNING Missing Expected Field 'booktitle' from entry song2017content: " Content-type coding  "
# WARNING Missing Expected Field 'booktitle' from entry song2016deterministic: " A deterministic algorithm for  ... "
# WARNING Missing Expected Field 'booktitle' from entry song2016stream: " Stream-based online active lea ... "
# WARNING Missing Expected Field 'booktitle' from entry song2018making: " Making recommendations bandwid ... "
# SUCESSFULLY PARSED karmoose2017private: " Private broadcasting: An index coding approach  "
# SUCESSFULLY PARSED song2017pliable: " A pliable index coding approach to data shuffling  "
# WARNING Missing Expected Field 'booktitle' from entry song2017contextual: " A contextual bandit approach f ... "
# SUCESSFULLY PARSED karmoose2017preserving: " Preserving privacy while broadcasting: K-limited-access sche ... "
# SUCESSFULLY PARSED song2017benefit: " The benefit of being flexible in distributed computation  "
# SUCESSFULLY PARSED karmoose2018privacy: " Privacy in index coding: Improved bounds and coding schemes  "
# SUCESSFULLY PARSED song2016polynomial: " A polynomial-time algorithm for pliable index coding  "
# WARNING Missing Expected Field 'booktitle' from entry song2018polynomial: " A polynomial-time algorithm fo ... "
# SUCESSFULLY PARSED srinivasavaradhan2018distributed: " Distributed computing trade-offs with random connectivity  "
# WARNING Missing Expected Field 'booktitle' from entry song2019pliable: " A pliable index coding approac ... "
# SUCESSFULLY PARSED song2018dynamic: " Dynamic edge caching with popularity drifting  "
# WARNING Missing Expected Field 'booktitle' from entry karmoose2019privacy: " Privacy in index coding: $ k $ ... "
# WARNING Missing Expected Field 'booktitle' from entry song2018regret: " Regret vs. bandwidth trade-off ... "
# SUCESSFULLY PARSED song2018recommender: " Recommender systems over wireless: Challenges and opportunit ... "
# SUCESSFULLY PARSED song2018binary: " A binary randomized coding scheme for pliable index coding w ... "
# SUCESSFULLY PARSED data2018data: " Data encoding for Byzantine-resilient distributed gradient d ... "
# WARNING Missing Expected Field 'booktitle' from entry bao2019equivariant: " Equivariant neural networks an ... "
# SUCESSFULLY PARSED song2019active: " Active learning for streaming data in a contextual bandit fr ... "
# WARNING Missing Expected Field 'booktitle' from entry data2020data: " Data encoding for byzantine-re ... "
# WARNING Missing Expected Field 'booktitle' from entry yang2019tradeoff: " The tradeoff between privacy a ... "
# WARNING Missing Expected Field 'booktitle' from entry chen2019collaborative: " Collaborative content placemen ... "
# SUCESSFULLY PARSED tang2019scheduling: " Scheduling to minimize age of information in multi-state tim ... "
# SUCESSFULLY PARSED song2019interactions: " Interactions between learning and broadcasting in wireless r ... "
# SUCESSFULLY PARSED data2019data: " Data encoding methods for byzantine-resilient distributed op ... "
# SUCESSFULLY PARSED li2019deep: " Deep reinforcement learning based residential demand side ma ... "
# SUCESSFULLY PARSED bai2019bayesian: " Bayesian Stackelberg game for risk-aware edge computation of ... "
# WARNING Missing Expected Field 'booktitle' from entry bai2020risk: " Risk-aware edge computation of ... "
# SUCESSFULLY PARSED li2020federated: " Federated recommendation system via differential privacy  "
# WARNING Missing Expected Field 'booktitle' from entry zhao2020energy: " Energy-optimal and delay-bound ... "
# SUCESSFULLY PARSED shi2019privacy: " Privacy-aware edge computing based on adaptive DNN partition ... "
# SUCESSFULLY PARSED he2020coded: " Coded caching with heterogeneous user groups  "
# WARNING Missing Expected Field 'booktitle' from entry li2020wireless: " Wireless recommendations for I ... "
# SUCESSFULLY PARSED chen2020enhancing: " Enhancing deep multimedia recommendations using graph embedd ... "
# WARNING Missing Expected Field 'booktitle' from entry linqi2017content: " Content-Type Coding  "
# SUCESSFULLY PARSED xu2020semantic: " Semantic role labeling guided multi-turn dialogue rewriter  "
# SUCESSFULLY PARSED li2020secrecy: " On secrecy key of a class of secure asymmetric multilevel di ... "
# SUCESSFULLY PARSED zhang2019preventing: " Preventing malware propagation in D2D offloading networks wi ... "
# WARNING Missing Expected Field 'booktitle' from entry dong2020distributed: " Distributed Thompson Sampling  "
# WARNING Missing Expected Field 'booktitle' from entry huang2022egfi: " EGFI: drug--drug interaction e ... "
# WARNING Missing Expected Field 'booktitle' from entry chen2021whittle: " A whittle index approach to mi ... "
# WARNING Missing Expected Field 'booktitle' from entry xu2021conversational: " Conversational semantic role l ... "
# WARNING Missing Expected Field 'booktitle' from entry mao2022communication: " Communication-efficient federa ... "
# SUCESSFULLY PARSED xu2021live: " Live gradient compensation for evading stragglers in distrib ... "
# WARNING Missing Expected Field 'booktitle' from entry li2021integrating: " Integrating future smart home  ... "
# SUCESSFULLY PARSED wang2021coded: " Coded alternating least squares for straggler mitigation in  ... "
# SUCESSFULLY PARSED wu2021domain: " Domain-adaptive pretraining methods for dialogue understandi ... "
# WARNING Missing Expected Field 'booktitle' from entry liu2022recent: " Recent advances in biometrics- ... "
# SUCESSFULLY PARSED yan2021dq: " DQ-SGD: Dynamic quantization in SGD for communication-effici ... "
# SUCESSFULLY PARSED he2021k: " K-CSRL: Knowledge enhanced conversational semantic role labe ... "
# SUCESSFULLY PARSED vestergaard2021coded: " On Coded Broadcasting for Wireless Recommendation Systems  "
# SUCESSFULLY PARSED xu2021racial: " Racial Bias During “Black Lives Matter”: How Social Movement ... "
# SUCESSFULLY PARSED wu2021csagn: " CSAGN: Conversational structure aware graph network for conv ... "
# WARNING Missing Expected Field 'booktitle' from entry li2022privacy: " Privacy-preserving communicati ... "
# SUCESSFULLY PARSED wu2022zero: " Zero-shot cross-lingual conversational semantic role labelin ... "
# WARNING Missing Expected Field 'booktitle' from entry xue2021evolutionary: " Evolutionary sequential transf ... "
# WARNING Missing Expected Field 'booktitle' from entry linqi2020pliable: " A pliable index coding approac ... "
# WARNING Missing Expected Field 'booktitle' from entry xue2022divide: " A divide-and-conquer optimizat ... "
# SUCESSFULLY PARSED tan2022sentence: " A sentence is worth 128 pseudo tokens: A semantic-aware cont ... "
# WARNING Missing Expected Field 'booktitle' from entry sichun2021一種基於推薦服務器及子系統的推薦系統及方法: " 一種基於推薦服務器及子系統的推薦系統及方法  "
# WARNING Missing Expected Field 'booktitle' from entry ding2022sensing: " Sensing, processing, computing ... "
# SUCESSFULLY PARSED xu2022byzantine: " Byzantine-robust federated learning through collaborative ma ... "
# SUCESSFULLY PARSED li2022federated: " Federated adaptive bandits aided caching for heterogeneous e ... "
# WARNING Missing Expected Field 'booktitle' from entry wu2022learning: " Learning locality and isotropy ... "
# SUCESSFULLY PARSED li2021predicting: " Predicting downside in stock market using knowledge and news ... "
# WARNING Missing Expected Field 'booktitle' from entry tang2020minimizing: " Minimizing age of information  ... "
# SUCESSFULLY PARSED shao2022towards: " Towards better understanding with uniformity and explicit re ... "
# WARNING Missing Expected Field 'booktitle' from entry sichun2022recommender: " Recommender System And Its Ope ... "
# WARNING Missing Expected Field 'booktitle' from entry sichun2023federated: " Federated Recommendation Syste ... "
# WARNING Missing Expected Field 'booktitle' from entry yan2022ac: " AC-SGD: Adaptively compressed  ... "
# WARNING Missing Expected Field 'booktitle' from entry zhao2023towards: " Towards efficient communicatio ... "
# SUCESSFULLY PARSED luo2022towards: " Towards communication efficient and fair federated personali ... "
# SUCESSFULLY PARSED luo2022personalized: " Personalized federated recommendation via joint representati ... "
# SUCESSFULLY PARSED luo2022hysage: " HySAGE: A hybrid static and adaptive graph embedding network ... "
# WARNING Missing Expected Field 'booktitle' from entry huang2022federated: " Federated multi-task learning  ... "
# SUCESSFULLY PARSED hu2022dual: " A dual-stage pseudo-labeling method for the diagnosis of men ... "
# WARNING Missing Expected Field 'booktitle' from entry hu2022communication: " Communication efficient federa ... "
# WARNING Missing Expected Field 'booktitle' from entry chen2022hiding: " Hiding images in deep probabil ... "
# SUCESSFULLY PARSED ruan2023adaptive: " Adaptive Top-K in SGD for communication-efficient distribute ... "
# SUCESSFULLY PARSED yang2023vehicle: " Vehicle-key: A secret key establishment scheme for LoRa-enab ... "
# WARNING Missing Expected Field 'booktitle' from entry wei2022一種情緒預測方法: " 一種情緒預測方法, 裝置, 計算機設備及存儲介質  "
# SUCESSFULLY PARSED duan2022facial: " Facial expression recognition based on data augmentation and ... "
# SUCESSFULLY PARSED liu2022speech: " Speech emotion recognition based on deep learning  "
# WARNING Missing Expected Field 'booktitle' from entry luo2023influential: " Influential factors in custome ... "
# SUCESSFULLY PARSED liu2022federated: " Federated multi-armed bandits with vector rewards for aspect ... "
# WARNING Missing Expected Field 'booktitle' from entry li2023federated: " Federated online learning aide ... "
# WARNING Missing Expected Field 'booktitle' from entry xue2025scalable: " A scalable test problem genera ... "
# WARNING Missing Expected Field 'booktitle' from entry yang2023achieving: " Achieving privacy-preserving c ... "
# WARNING Missing Expected Field 'booktitle' from entry yan2024killing: " Killing two birds with one sto ... "
# SUCESSFULLY PARSED wu2023vcsum: " Vcsum: A versatile chinese meeting summarization dataset  "
# WARNING Missing Expected Field 'booktitle' from entry luo2024perfedrec++: " Perfedrec++: Enhancing persona ... "
# WARNING Missing Expected Field 'booktitle' from entry tan2023self: " Self-Supervised Sentence Compr ... "
# WARNING Missing Expected Field 'booktitle' from entry song2023emma: " Emma: An accurate, efficient,  ... "
# SUCESSFULLY PARSED liu2022nlp: " An NLP-empowered virtual course assistant for online teachin ... "
# SUCESSFULLY PARSED wang2022designing: " Designing an educational chatbot with joint intent classific ... "
# SUCESSFULLY PARSED xu2022digital: " Digital Social Movements and the Performance of Sharing Econ ... "
# WARNING Missing Expected Field 'booktitle' from entry hu2023source: " Source free semi-supervised tr ... "
# WARNING Missing Expected Field 'booktitle' from entry sichun2023training: " Training And Operating Neural  ... "
# WARNING Missing Expected Field 'booktitle' from entry sichun2023training2: " Training And/Or Operating Grap ... "
# SUCESSFULLY PARSED zhou2024solving: " Solving Challenging Math Word Problems Using GPT-4 Code Inte ... "
# WARNING Missing Expected Field 'booktitle' from entry zhang2023crossvision: " Crossvision: Real-time on-came ... "
# WARNING Missing Expected Field 'booktitle' from entry song2023unmanned: " Unmanned Aerial Vehicle Platfo ... "
# SUCESSFULLY PARSED wang2024mathcoder: " Mathcoder: Seamless code integration in llms for enhanced ma ... "
# SUCESSFULLY PARSED yao2023fine: " Fine-grained conversational decoding via isotropic and proxi ... "
# WARNING Missing Expected Field 'booktitle' from entry zhang2023hepm: " HEPM: High-efficiency pattern  ... "
# WARNING Missing Expected Field 'booktitle' from entry sun2023pruning: " A pruning-then-quantization mo ... "
# SUCESSFULLY PARSED luo2023improving: " Improving long-tail item recommendation with graph augmentat ... "
# SUCESSFULLY PARSED huang2024clomo: " Clomo: Counterfactual logical modification with large langua ... "
# SUCESSFULLY PARSED tan2023reconstruct: " Reconstruct before summarize: An efficient two-step framewor ... "
# SUCESSFULLY PARSED hou2023mds: " On the MDS Condition of Generalized Expanded-Blaum-Roth Code ... "
# WARNING Missing Expected Field 'booktitle' from entry yan2025layered: " Layered randomized quantizatio ... "
# WARNING Missing Expected Field 'booktitle' from entry wu2023structure: " Structure-aware dialogue model ... "
# WARNING Missing Expected Field 'booktitle' from entry xue2023solution: " Solution transfer in evolution ... "
# WARNING Missing Expected Field 'booktitle' from entry luo2025recranker: " RecRanker: Instruction Tuning  ... "
# WARNING Missing Expected Field 'booktitle' from entry luo2026federated: " Federated recommendation syste ... "
# WARNING Missing Expected Field 'booktitle' from entry huang2023special: " Special issue on non-determini ... "
# WARNING Missing Expected Field 'booktitle' from entry luo2026integrating: " Integrating large language mod ... "
# SUCESSFULLY PARSED yu2023product: " Product-matrix construction of minimum storage rack-aware re ... "
# SUCESSFULLY PARSED hou2023triple: " Triple-fault-tolerant binary mds array codes with lower enco ... "
# SUCESSFULLY PARSED li2023fast: " A Fast Algorithm for Finding the Roots of Polynomials over F ... "
# SUCESSFULLY PARSED wang2023matrix: " Matrix Completion via Coded Distributed Alternating Least Sq ... "
# SUCESSFULLY PARSED yan2024truncated: " Truncated Non-Uniform quantization for distributed SGD  "
# WARNING Missing Expected Field 'booktitle' from entry yan2024improved: " Improved Quantization Strategi ... "
# SUCESSFULLY PARSED huang2024mustard: " Mustard: Mastering uniform synthesis of theorem and proof da ... "
# SUCESSFULLY PARSED li2024understanding: " Understanding and patching compositional reasoning in llms  "
# WARNING Missing Expected Field 'booktitle' from entry chen2023gap: " Gap-closing matters: Perceptua ... "
# SUCESSFULLY PARSED luo2023framework: " A framework of large-scale peer-to-peer learning system  "
# SUCESSFULLY PARSED yao2024can: " Can LLM substitute human labeling? A case study of fine-grai ... "
# WARNING Missing Expected Field 'booktitle' from entry cao2024competitive: " Competitive knowledge transfer ... "
# SUCESSFULLY PARSED luo2024large: " Large language models augmented rating prediction in recomme ... "
# WARNING Missing Expected Field 'booktitle' from entry yao2024learning: " Learning from correctness with ... "
# WARNING Missing Expected Field 'booktitle' from entry luo2024language: " A language model-based fine-gr ... "
# WARNING Missing Expected Field 'booktitle' from entry ruan2024adaptive: " Adaptive top-k in SGD for comm ... "
# SUCESSFULLY PARSED zhong2024benchmarking: " Benchmarking and improving compositional generalization of m ... "
# SUCESSFULLY PARSED liu2024reed: " Reed-Solomon codes over cyclic polynomial ring with lower en ... "
# SUCESSFULLY PARSED zhang2023semantic: " Semantic Communication Based on Entity Information Enhanceme ... "
# WARNING Missing Expected Field 'booktitle' from entry luo2024privacy: " Privacy in LLM-based recommend ... "
# SUCESSFULLY PARSED liu2024bi: " Bi-chainer: automated large language models reasoning with b ... "
# WARNING Missing Expected Field 'booktitle' from entry liu2024towards: " Towards Improving Interpretabi ... "
# WARNING Missing Expected Field 'booktitle' from entry luo2024recommender: " Recommender system and its ope ... "
# WARNING Missing Expected Field 'year' from entry yuxuan2023fine: " Fine-grained Conversational De ... "
# WARNING Missing Expected Field 'booktitle' from entry zhu2024video: " Video quality assessment for s ... "
# WARNING Missing Expected Field 'booktitle' from entry lin2024fvel: " Fvel: Interactive formal verif ... "
# WARNING Missing Expected Field 'booktitle' from entry jiang2024interpretable: " Interpretable catastrophic for ... "
# WARNING Missing Expected Field 'booktitle' from entry yang2024scenario: " Scenario-adaptive key establis ... "
# WARNING Missing Expected Field 'booktitle' from entry sichun2024基於訓練和: " 基於訓練和/或操作圖神經網絡的推薦系統  "
# WARNING Missing Expected Field 'booktitle' from entry yang2024benchmarking: " Benchmarking llms for optimiza ... "
# WARNING Missing Expected Field 'booktitle' from entry qian2024octrack: " Octrack: benchmarking the open ... "
# WARNING Missing Expected Field 'booktitle' from entry wu20243d: " 3d shape completion on unseen  ... "
# WARNING Missing Expected Field 'booktitle' from entry su2024lightweight: " Lightweight instantly decodabl ... "
# WARNING Missing Expected Field 'booktitle' from entry lin2024rotation: " Rotation and permutation for a ... "
# WARNING Missing Expected Field 'booktitle' from entry jiang2025error: " Error correction decoding algo ... "
# SUCESSFULLY PARSED xue2024multiobjective: " Multiobjective sequential transfer optimization: Benchmark p ... "
# WARNING Missing Expected Field 'booktitle' from entry xue2024surrogate: " Surrogate-assisted search with ... "
# SUCESSFULLY PARSED wu2024multiobjective: " Multiobjective bayesian optimization for antenna placement i ... "
# SUCESSFULLY PARSED jiang2024tight: " Tight lower bound on cross-rack update bandwidth and explici ... "
# SUCESSFULLY PARSED zhu2024new: " New EVENODD+ Codes with More Flexible Parameters and Lower C ... "
# SUCESSFULLY PARSED zhang2024rethinking: " Rethinking the one-shot object detection: Cross-domain objec ... "
# SUCESSFULLY PARSED hu2024heterogeneous: " Heterogeneous structured federated learning with graph convo ... "
# SUCESSFULLY PARSED wang2024lightweight: " Lightweight Instantly Decodable Network Coding in Wireless B ... "
# SUCESSFULLY PARSED yao2025determine: " Determine-then-ensemble: Necessity of top-k union for large  ... "
# SUCESSFULLY PARSED wang2024mitigating: " Mitigating the language mismatch and repetition issues in ll ... "
# WARNING Missing Expected Field 'booktitle' from entry lin2024duquant: " Duquant: Distributing outliers ... "
# WARNING Missing Expected Field 'booktitle' from entry zhang2025short: " Short-sighted knowledge discov ... "
# WARNING Missing Expected Field 'booktitle' from entry qian2024vovtrack: " Vovtrack: Exploring the potent ... "
# SUCESSFULLY PARSED yang2025optibench: " Optibench meets resocratic: Measure and improve llms for opt ... "
# WARNING Missing Expected Field 'booktitle' from entry zhang2024synthetic: " From Synthetic to Real: Unveil ... "
# SUCESSFULLY PARSED li2024loran: " Loran: Improved low-rank adaptation by a non-linear transfor ... "
# WARNING Missing Expected Field 'booktitle' from entry zhang2026incremental: " Incremental Skyline Frequent-U ... "
# WARNING Missing Expected Field 'booktitle' from entry xu2024cooperative: " Cooperative multi-model traini ... "
# WARNING Missing Expected Field 'booktitle' from entry xu2024integrated: " Integrated object detection an ... "
# WARNING Missing Expected Field 'booktitle' from entry yang2024iresnetdm: " iResNetDM: an interpretable de ... "
# SUCESSFULLY PARSED ruan2024optimal: " Optimal power control for over-the-air federated learning wi ... "
# WARNING Missing Expected Field 'booktitle' from entry zhang2025enabling: " Enabling knowledge discovery t ... "
# WARNING Missing Expected Field 'booktitle' from entry luo2024training: " Training and operating neural  ... "
# SUCESSFULLY PARSED yang2025mhmg: " mHMG-DTI: a drug-target interaction prediction framework com ... "
# SUCESSFULLY PARSED li2024new: " New Cauchy MDS array codes with flexible sub-packetization a ... "
# SUCESSFULLY PARSED yan2024towards: " Towards Quantum-Safe Distributed Learning via Homomorphic En ... "
# SUCESSFULLY PARSED liu2024cost: " On the I/O Cost of Linear Repair Schemes for Arbitrary $(n,  ... "
# SUCESSFULLY PARSED wang2024addressing: " Addressing Fluctuating Stragglers in Distributed Matrix Mult ... "
# SUCESSFULLY PARSED shao2025diffetm: " Diffetm: Diffusion process enhanced embedded topic model  "
# SUCESSFULLY PARSED lin2024fast: " Fast Erasure Decoding of Reed-Solomon Codes Based on Decompo ... "
# SUCESSFULLY PARSED li2024communication: " Communication-Efficient Multi-Modal Federated Learning via D ... "
# WARNING Missing Expected Field 'booktitle' from entry shi2025accelerating: " Accelerating Data Access for S ... "
# WARNING Missing Expected Field 'booktitle' from entry liu2025massive: " Massive Random Access Control  ... "
# SUCESSFULLY PARSED xu2025rallrec: " Rallrec: Improving retrieval augmented large language model  ... "
# WARNING Missing Expected Field 'booktitle' from entry zhou2025learning: " Learning and grounding visual  ... "
# WARNING Missing Expected Field 'booktitle' from entry luo2025training: " Training and/or operating grap ... "
# WARNING Missing Expected Field 'booktitle' from entry liu2025optishear: " Optishear: Towards efficient a ... "
# WARNING Missing Expected Field 'booktitle' from entry liu20251bit: " 1bit-merging: Dynamic quantize ... "
# SUCESSFULLY PARSED jiang2025unlocking: " Unlocking the Power of Function Vectors for Characterizing a ... "
# WARNING Missing Expected Field 'booktitle' from entry ling2025communication: " Communication-Efficient and Pr ... "
# WARNING Missing Expected Field 'booktitle' from entry shuqi2025towards: " Towards Efficient Adaptation o ... "
# WARNING Missing Expected Field 'booktitle' from entry song2019minimizing: " Minimizing age of information  ... "
# WARNING Missing Expected Field 'booktitle' from entry liu2025sens: " Sens-Merging: Sensitivity-Guid ... "
# WARNING Missing Expected Field 'booktitle' from entry zhang2025skyline: " Skyline recency--frequency--mo ... "
# WARNING Missing Expected Field 'booktitle' from entry luo2025rallrec+: " RALLRec+: Retrieval augmented  ... "
# WARNING Missing Expected Field 'booktitle' from entry wang2025subnetwork: " Subnetwork Knowledge Injection ... "
# WARNING Missing Expected Field 'booktitle' from entry luo2025reasoning: " Reasoning meets personalizatio ... "
# WARNING Missing Expected Field 'booktitle' from entry zhang2025synthetic: " Synthetic-to-real video person ... "
# SUCESSFULLY PARSED jiang2025makes: " What makes a good reasoning chain? uncovering structural pat ... "
# WARNING Missing Expected Field 'booktitle' from entry yao2026activation: " Activation-guided consensus me ... "
# SUCESSFULLY PARSED tan2024proxyqa: " {P}roxy{QA}: An Alternative Framework for Evaluating Long-Fo ... "
# SUCESSFULLY PARSED lin2024mope: " Mope-clip: Structured pruning for efficient vision-language  ... "
# WARNING Missing Expected Field 'booktitle' from entry song2014cemtekin: " CemTekin, and Mihaela van der  ... "
# WARNING Missing Expected Field 'booktitle' from entry liang2025low: " A low-complexity BP-OSD algori ... "
# WARNING Missing Expected Field 'booktitle' from entry liu2025reasoning: " Reasoning in Action: MCTS-Driv ... "
# WARNING Missing Expected Field 'year' from entry yao2403learning: " Learning from correctness with ... "
# WARNING Missing Expected Field 'booktitle' from entry yao2025leveraging: " Leveraging Correctness-Based L ... "
# WARNING Missing Expected Field 'booktitle' from entry xu2025multimodal: " Multimodal Named Entity Recogn ... "
# WARNING Missing Expected Field 'booktitle' from entry yu2025explicit: " Explicit constructions of rack ... "
# WARNING Missing Expected Field 'booktitle' from entry liu2025beyond: " Beyond One-Size-Fits-All Pruni ... "
# WARNING Missing Expected Field 'booktitle' from entry yang2025drugmcts: " Drugmcts: a drug repurposing f ... "
# WARNING Missing Expected Field 'booktitle' from entry guanzhi2026hybrid: " Hybrid Llm-Knowledge Graph Sys ... "
# WARNING Missing Expected Field 'booktitle' from entry deng2025klipa: " KLIPA: a knowledge graph and L ... "
# SUCESSFULLY PARSED wang2025low: " Low-Complexity BP-ORBOSD Algorithm for Short 5G LDPC Codes  "
# WARNING Missing Expected Field 'booktitle' from entry deng2025enhancing: " Enhancing Low-Rank Adaptation  ... "
# WARNING Missing Expected Field 'booktitle' from entry li2025rema: " Rema: A unified reasoning mani ... "
# SUCESSFULLY PARSED qian2025vovtrack: " VOVTrack: exploring the potentiality in raw videos for open- ... "
# WARNING Missing Expected Field 'year' from entry qianvovtrack: " VOVTrack: Exploring the Potent ... "
# WARNING Missing Expected Field 'booktitle' from entry wang2025low2: " Low-complexity ordered statist ... "
# WARNING Missing Expected Field 'booktitle' from entry wang2025two: " A two-stage soft-decision deco ... "
# WARNING Missing Expected Field 'booktitle' from entry luo2026exploring: " Exploring the potential of lar ... "
# WARNING Missing Expected Field 'booktitle' from entry li2025client: " Client association and resourc ... "
# WARNING Missing Expected Field 'booktitle' from entry sichun2024用於訓練基於神經網絡的排序模型的計算機實現方法和系統: " 用於訓練基於神經網絡的排序模型的計算機實現方法和系統  "
# WARNING Missing Expected Field 'booktitle' from entry liang2025belief: " Belief propagation-ordered sta ... "
# WARNING Missing Expected Field 'booktitle' from entry liu2025dual: " Dual-perspective hypergraph le ... "
# WARNING Missing Expected Field 'booktitle' from entry xu2025jmucod: " JMUCOD: joint maritime-underwa ... "
# WARNING Missing Expected Field 'booktitle' from entry liu2026ucb: " A UCB Bandit Algorithm for Gen ... "
# WARNING Missing Expected Field 'booktitle' from entry zhang2026dsa: " DSA-Tokenizer: Disentangled Se ... "
# WARNING Missing Expected Field 'booktitle' from entry yang2026memo: " Memo-SQL: Structured Decomposi ... "
# WARNING Missing Expected Field 'year' from entry wangunderstanding: " Understanding Before Evaluatio ... "
# SUCESSFULLY PARSED wang2026temperature: " On Temperature-Constrained Non-Deterministic Machine Transla ... "
# WARNING Missing Expected Field 'booktitle' from entry jiang2026cross: " Cross-Rack Update Bandwidth fo ... "
# WARNING Missing Expected Field 'booktitle' from entry wang2025bp: " BP-LCGCD: A Gaussian-eliminati ... "
# WARNING Missing Expected Field 'booktitle' from entry wang2025robust: " Robust Federated Learning unde ... "
# WARNING Missing Expected Field 'booktitle' from entry li2026scaling: " Scaling Reasoning Hop Exposes  ... "
# WARNING Missing Expected Field 'booktitle' from entry yao2026merging: " Merging Beyond: Streaming LLM  ... "
# WARNING Missing Expected Field 'booktitle' from entry wang2026multi: " Multi-Matrix Representative Or ... "
# WARNING Missing Expected Field 'booktitle' from entry liu2026efficient: " Efficient Encoding/Decoding Al ... "
# WARNING Missing Expected Field 'year' from entry zeruiexpesql: " ExpeSQL: An Experience-Guided  ... "
# WARNING Missing Expected Field 'booktitle' from entry xu2026self: " A self-modified hypergraph neu ... "
# SUCESSFULLY PARSED zhou2025cross: " A Cross-Modal Information Retrieval Framework Based on an In ... "
# WARNING Missing Expected Field 'booktitle' from entry shao2026towards: " Towards Privacy-Preserving Mac ... "
# SUCESSFULLY PARSED wang2025reduced: " Reduced-complexity guessing codeword decoding of BCH codes w ... "
# WARNING Missing Expected Field 'booktitle' from entry li2026role: " On the Role of Reasoning Patte ... "
# WARNING Missing Expected Field 'booktitle' from entry liu2026corrigendum: " Corrigendum to “Dual-perspecti ... "
# WARNING Missing Expected Field 'booktitle' from entry cao2026systradebench: " SysTradeBench: An Iterative Bu ... "
# WARNING Missing Expected Field 'booktitle' from entry jian2026forge: " FORGE: Fine-grained multimodal ... "
# WARNING Missing Expected Field 'booktitle' from entry su2026grand: " On GRAND-Assisted Vector Rando ... "
# SUCESSFULLY PARSED wang2025maximum: " A maximum-likelihood decoding of bch codes  "
# WARNING Missing Expected Field 'booktitle' from entry li2026learning: " Learning to Reason with Insigh ... "
# WARNING Missing Expected Field 'booktitle' from entry fan2026parm: " PARM: Pipeline-Adapted Reward  ... "
# SUCESSFULLY PARSED yang2026spatially: " Spatially-Coupled OTFS Systems via Block Markov Superpositio ... "
# WARNING Missing Expected Field 'booktitle' from entry tan2024flexible: " Flexible Coded Distributed Con ... "
# WARNING Missing Expected Field 'booktitle' from entry liu2026dual: " Dual-perspective hypergraph le ... "
# WARNING Missing Expected Field 'booktitle' from entry deng2026routing: " Routing-Aligned Fine-Tuning fo ... "
# WARNING Missing Expected Field 'booktitle' from entry zhang2026speecheditbench: " SpeechEditBench: A Bilingual M ... "
# WARNING Missing Expected Field 'booktitle' from entry liu2026long: " From Long News to Accurate For ... "
# WARNING Missing Expected Field 'booktitle' from entry wong2026automated: " Automated Proving of Shannon-T ... "
# WARNING Missing Expected Field 'booktitle' from entry liu2026reasonalloc: " ReasonAlloc: Hierarchical Deco ... "
# WARNING Missing Expected Field 'booktitle' from entry liu2026power: " Power and Interference Managem ... "
# SUCESSFULLY PARSED wang2026ge: " GE-Free BP-OSD for Short 5G LDPC Codes  "
# SUCESSFULLY PARSED wu2026generalizing: " Generalizing the Outage Minimization Problem in Wireless Ran ... "
# SUCESSFULLY PARSED wang2026gaussian: " Gaussian Elimination-Free OSD via Pre-Stored Matrices  "
# SUCESSFULLY PARSED wang2026resu: " Resu: A Regularized and Non-monotonic Activation Function fo ... "
# WARNING Missing Expected Field 'booktitle' from entry wu2026lavit: " Lavit: Aligning latent visual  ... "
# WARNING Missing Expected Field 'booktitle' from entry zhang2026multimodal: " Multimodal emotion recognition ... "
# WARNING Missing Expected Field 'booktitle' from entry zhang2026vl: " VL-DINO: Leveraging CLIP Visio ... "
# WARNING Missing Expected Field 'booktitle' from entry shao2021pattern: " A pattern and POS auto-learnin ... "
# SUCESSFULLY PARSED zerui2026memo: " Memo-SQL: Structured Decomposition and Experience-Driven Sel ... "
# WARNING Missing Expected Field 'booktitle' from entry li2026demopsd: " DemoPSD: Disagreement-Modulate ... "
# WARNING Missing Expected Field 'booktitle' from entry xu2026data: " Data augmentation with entity- ... "
# WARNING Missing Expected Field 'booktitle' from entry wang2026gaussian2: " Gaussian-Elimination-Free Orde ... "
# SUCESSFULLY PARSED wang2026multiple: " Multiple-Cyclic-Basis GCD for BCH Codes  "
# WARNING Missing Expected Field 'booktitle' from entry liu2026optical: " Optical Reflecting Intelligent ... "
# WARNING Missing Expected Field 'booktitle' from entry wang2026partial: " Partial-Superposition HARQ for ... "
# WARNING Missing Expected Field 'booktitle' from entry deng2026dr: " DR-LoRA: Dynamic Rank LoRA for ... "
# WARNING Missing Expected Field 'booktitle' from entry wang2026gaussian3: " Gaussian-Elimination-Free BP-O ... "
# WARNING Missing Expected Field 'booktitle' from entry deng2026texas: " TEXAS: Task-Expert-Aware Super ... "
# WARNING Missing Expected Field 'booktitle' from entry zhang2026speaker: " Speaker-Normalized Semantic Sp ... "
# WARNING Missing Expected Field 'journal' from entry song2008normalized: " A normalized LLR soft informat ... "
# WARNING Missing Expected Field 'journal' from entry song2014clustering: " Clustering based online learni ... "
# SUCESSFULLY PARSED song2016online: " Online Learning in Large-scale Contextual Recommender System ... "
# WARNING Missing Expected Field 'journal' from entry xu2014context: " Context-driven online learning ... "
# SUCESSFULLY PARSED song2014demand: " Demand side management in smart grids using a repeated game  ... "
# WARNING Missing Expected Field 'journal' from entry song2014non: " Non-stationary demand side man ... "
# SUCESSFULLY PARSED xu2016personalized: " Personalized active learning for activity classification usi ... "
# SUCESSFULLY PARSED song2015using: " Using contextual learning to improve diagnostic accuracy: Ap ... "
# WARNING Missing Expected Field 'journal' from entry song2017content: " Content-type coding  "
# SUCESSFULLY PARSED song2016deterministic: " A deterministic algorithm for pliable index coding  "
# SUCESSFULLY PARSED song2016stream: " Stream-based online active learning in a contextual multi-ar ... "
# SUCESSFULLY PARSED song2018making: " Making recommendations bandwidth aware  "
# WARNING Missing Expected Field 'journal' from entry karmoose2017private: " Private broadcasting: An index ... "
# WARNING Missing Expected Field 'journal' from entry song2017pliable: " A pliable index coding approac ... "
# SUCESSFULLY PARSED song2017contextual: " A contextual bandit approach for stream-based active learnin ... "
# WARNING Missing Expected Field 'journal' from entry karmoose2017preserving: " Preserving privacy while broad ... "
# WARNING Missing Expected Field 'journal' from entry song2017benefit: " The benefit of being flexible  ... "
# WARNING Missing Expected Field 'journal' from entry karmoose2018privacy: " Privacy in index coding: Impro ... "
# WARNING Missing Expected Field 'journal' from entry song2016polynomial: " A polynomial-time algorithm fo ... "
# SUCESSFULLY PARSED song2018polynomial: " A polynomial-time algorithm for pliable index coding  "
# WARNING Missing Expected Field 'journal' from entry srinivasavaradhan2018distributed: " Distributed computing trade-of ... "
# SUCESSFULLY PARSED song2019pliable: " A pliable index coding approach to data shuffling  "
# WARNING Missing Expected Field 'journal' from entry song2018dynamic: " Dynamic edge caching with popu ... "
# SUCESSFULLY PARSED karmoose2019privacy: " Privacy in index coding: $ k $-limited-access schemes  "
# SUCESSFULLY PARSED song2018regret: " Regret vs. bandwidth trade-off for recommendation systems  "
# WARNING Missing Expected Field 'journal' from entry song2018recommender: " Recommender systems over wirel ... "
# WARNING Missing Expected Field 'journal' from entry song2018binary: " A binary randomized coding sch ... "
# WARNING Missing Expected Field 'journal' from entry data2018data: " Data encoding for Byzantine-re ... "
# SUCESSFULLY PARSED bao2019equivariant: " Equivariant neural networks and equivarification  "
# WARNING Missing Expected Field 'journal' from entry song2019active: " Active learning for streaming  ... "
# SUCESSFULLY PARSED data2020data: " Data encoding for byzantine-resilient distributed optimizati ... "
# SUCESSFULLY PARSED yang2019tradeoff: " The tradeoff between privacy and accuracy in anomaly detecti ... "
# SUCESSFULLY PARSED chen2019collaborative: " Collaborative content placement among wireless edge caching  ... "
# WARNING Missing Expected Field 'journal' from entry tang2019scheduling: " Scheduling to minimize age of  ... "
# WARNING Missing Expected Field 'journal' from entry song2019interactions: " Interactions between learning  ... "
# WARNING Missing Expected Field 'journal' from entry data2019data: " Data encoding methods for byza ... "
# WARNING Missing Expected Field 'journal' from entry li2019deep: " Deep reinforcement learning ba ... "
# WARNING Missing Expected Field 'journal' from entry bai2019bayesian: " Bayesian Stackelberg game for  ... "
# SUCESSFULLY PARSED bai2020risk: " Risk-aware edge computation offloading using Bayesian Stacke ... "
# WARNING Missing Expected Field 'journal' from entry li2020federated: " Federated recommendation syste ... "
# SUCESSFULLY PARSED zhao2020energy: " Energy-optimal and delay-bounded computation offloading in m ... "
# WARNING Missing Expected Field 'journal' from entry shi2019privacy: " Privacy-aware edge computing b ... "
# WARNING Missing Expected Field 'journal' from entry he2020coded: " Coded caching with heterogeneo ... "
# SUCESSFULLY PARSED li2020wireless: " Wireless recommendations for Internet of vehicles: Recent ad ... "
# WARNING Missing Expected Field 'journal' from entry chen2020enhancing: " Enhancing deep multimedia reco ... "
# WARNING Missing Expected Field 'journal' from entry linqi2017content: " Content-Type Coding  "
# WARNING Missing Expected Field 'journal' from entry xu2020semantic: " Semantic role labeling guided  ... "
# WARNING Missing Expected Field 'journal' from entry li2020secrecy: " On secrecy key of a class of s ... "
# WARNING Missing Expected Field 'journal' from entry zhang2019preventing: " Preventing malware propagation ... "
# SUCESSFULLY PARSED dong2020distributed: " Distributed Thompson Sampling  "
# SUCESSFULLY PARSED huang2022egfi: " EGFI: drug--drug interaction extraction and generation with  ... "
# SUCESSFULLY PARSED chen2021whittle: " A whittle index approach to minimizing age of multi-packet i ... "
# SUCESSFULLY PARSED xu2021conversational: " Conversational semantic role labeling  "
# SUCESSFULLY PARSED mao2022communication: " Communication-efficient federated learning with adaptive qua ... "
# WARNING Missing Expected Field 'journal' from entry xu2021live: " Live gradient compensation for ... "
# SUCESSFULLY PARSED li2021integrating: " Integrating future smart home operation platform with demand ... "
# WARNING Missing Expected Field 'journal' from entry wang2021coded: " Coded alternating least square ... "
# WARNING Missing Expected Field 'journal' from entry wu2021domain: " Domain-adaptive pretraining me ... "
# SUCESSFULLY PARSED liu2022recent: " Recent advances in biometrics-based user authentication for  ... "
# WARNING Missing Expected Field 'journal' from entry yan2021dq: " DQ-SGD: Dynamic quantization i ... "
# WARNING Missing Expected Field 'journal' from entry he2021k: " K-CSRL: Knowledge enhanced con ... "
# WARNING Missing Expected Field 'journal' from entry vestergaard2021coded: " On Coded Broadcasting for Wire ... "
# WARNING Missing Expected Field 'journal' from entry xu2021racial: " Racial Bias During “Black Live ... "
# WARNING Missing Expected Field 'journal' from entry wu2021csagn: " CSAGN: Conversational structur ... "
# SUCESSFULLY PARSED li2022privacy: " Privacy-preserving communication-efficient federated multi-a ... "
# WARNING Missing Expected Field 'journal' from entry wu2022zero: " Zero-shot cross-lingual conver ... "
# SUCESSFULLY PARSED xue2021evolutionary: " Evolutionary sequential transfer optimization for objective- ... "
# SUCESSFULLY PARSED linqi2020pliable: " A pliable index coding approach to data shuffling  "
# SUCESSFULLY PARSED xue2022divide: " A divide-and-conquer optimization paradigm for waterflooding ... "
# WARNING Missing Expected Field 'journal' from entry tan2022sentence: " A sentence is worth 128 pseudo ... "
# WARNING Missing Expected Field 'journal' from entry sichun2021一種基於推薦服務器及子系統的推薦系統及方法: " 一種基於推薦服務器及子系統的推薦系統及方法  "
# SUCESSFULLY PARSED ding2022sensing: " Sensing, processing, computing and networking for the era of ... "
# WARNING Missing Expected Field 'journal' from entry xu2022byzantine: " Byzantine-robust federated lea ... "
# WARNING Missing Expected Field 'journal' from entry li2022federated: " Federated adaptive bandits aid ... "
# SUCESSFULLY PARSED wu2022learning: " Learning locality and isotropy in dialogue modeling  "
# WARNING Missing Expected Field 'journal' from entry li2021predicting: " Predicting downside in stock m ... "
# SUCESSFULLY PARSED tang2020minimizing: " Minimizing age of information with power constraints: Multi- ... "
# WARNING Missing Expected Field 'journal' from entry shao2022towards: " Towards better understanding w ... "
# WARNING Missing Expected Field 'journal' from entry sichun2022recommender: " Recommender System And Its Ope ... "
# WARNING Missing Expected Field 'journal' from entry sichun2023federated: " Federated Recommendation Syste ... "
# SUCESSFULLY PARSED yan2022ac: " AC-SGD: Adaptively compressed SGD for communication-efficien ... "
# SUCESSFULLY PARSED zhao2023towards: " Towards efficient communications in federated learning: A co ... "
# WARNING Missing Expected Field 'journal' from entry luo2022towards: " Towards communication efficien ... "
# WARNING Missing Expected Field 'journal' from entry luo2022personalized: " Personalized federated recomme ... "
# WARNING Missing Expected Field 'journal' from entry luo2022hysage: " HySAGE: A hybrid static and ad ... "
# SUCESSFULLY PARSED huang2022federated: " Federated multi-task learning for joint diagnosis of multipl ... "
# WARNING Missing Expected Field 'journal' from entry hu2022dual: " A dual-stage pseudo-labeling m ... "
# SUCESSFULLY PARSED hu2022communication: " Communication efficient federated learning with heterogeneou ... "
# SUCESSFULLY PARSED chen2022hiding: " Hiding images in deep probabilistic models  "
# WARNING Missing Expected Field 'journal' from entry ruan2023adaptive: " Adaptive Top-K in SGD for comm ... "
# WARNING Missing Expected Field 'journal' from entry yang2023vehicle: " Vehicle-key: A secret key esta ... "
# WARNING Missing Expected Field 'journal' from entry wei2022一種情緒預測方法: " 一種情緒預測方法, 裝置, 計算機設備及存儲介質  "
# WARNING Missing Expected Field 'journal' from entry duan2022facial: " Facial expression recognition  ... "
# WARNING Missing Expected Field 'journal' from entry liu2022speech: " Speech emotion recognition bas ... "
# SUCESSFULLY PARSED luo2023influential: " Influential factors in customer satisfaction of transit serv ... "
# WARNING Missing Expected Field 'journal' from entry liu2022federated: " Federated multi-armed bandits  ... "
# SUCESSFULLY PARSED li2023federated: " Federated online learning aided multi-objective proactive ca ... "
# SUCESSFULLY PARSED xue2025scalable: " A scalable test problem generator for sequential transfer op ... "
# SUCESSFULLY PARSED yang2023achieving: " Achieving privacy-preserving cross-silo anomaly detection us ... "
# SUCESSFULLY PARSED yan2024killing: " Killing two birds with one stone: Quantization achieves priv ... "
# WARNING Missing Expected Field 'journal' from entry wu2023vcsum: " Vcsum: A versatile chinese mee ... "
# SUCESSFULLY PARSED luo2024perfedrec++: " Perfedrec++: Enhancing personalized federated recommendation ... "
# SUCESSFULLY PARSED tan2023self: " Self-Supervised Sentence Compression for Meeting Summarizati ... "
# SUCESSFULLY PARSED song2023emma: " Emma: An accurate, efficient, and multi-modality strategy fo ... "
# WARNING Missing Expected Field 'journal' from entry liu2022nlp: " An NLP-empowered virtual cours ... "
# WARNING Missing Expected Field 'journal' from entry wang2022designing: " Designing an educational chatb ... "
# WARNING Missing Expected Field 'journal' from entry xu2022digital: " Digital Social Movements and t ... "
# SUCESSFULLY PARSED hu2023source: " Source free semi-supervised transfer learning for diagnosis  ... "
# WARNING Missing Expected Field 'journal' from entry sichun2023training: " Training And Operating Neural  ... "
# WARNING Missing Expected Field 'journal' from entry sichun2023training2: " Training And/Or Operating Grap ... "
# WARNING Missing Expected Field 'journal' from entry zhou2024solving: " Solving Challenging Math Word  ... "
# SUCESSFULLY PARSED zhang2023crossvision: " Crossvision: Real-time on-camera video analysis via common r ... "
# WARNING Missing Expected Field 'journal' from entry song2023unmanned: " Unmanned Aerial Vehicle Platfo ... "
# WARNING Missing Expected Field 'journal' from entry wang2024mathcoder: " Mathcoder: Seamless code integ ... "
# WARNING Missing Expected Field 'journal' from entry yao2023fine: " Fine-grained conversational de ... "
# SUCESSFULLY PARSED zhang2023hepm: " HEPM: High-efficiency pattern mining  "
# SUCESSFULLY PARSED sun2023pruning: " A pruning-then-quantization model compression framework for  ... "
# WARNING Missing Expected Field 'journal' from entry luo2023improving: " Improving long-tail item recom ... "
# WARNING Missing Expected Field 'journal' from entry huang2024clomo: " Clomo: Counterfactual logical  ... "
# WARNING Missing Expected Field 'journal' from entry tan2023reconstruct: " Reconstruct before summarize:  ... "
# WARNING Missing Expected Field 'journal' from entry hou2023mds: " On the MDS Condition of Genera ... "
# SUCESSFULLY PARSED yan2025layered: " Layered randomized quantization for communication-efficient  ... "
# SUCESSFULLY PARSED wu2023structure: " Structure-aware dialogue modeling methods for conversational ... "
# SUCESSFULLY PARSED xue2023solution: " Solution transfer in evolutionary optimization: An empirical ... "
# SUCESSFULLY PARSED luo2025recranker: " RecRanker: Instruction Tuning Large Language Model as Ranker ... "
# WARNING Missing Expected Field 'journal' from entry luo2026federated: " Federated recommendation syste ... "
# SUCESSFULLY PARSED huang2023special: " Special issue on non-deterministic machine learning  "
# SUCESSFULLY PARSED luo2026integrating: " Integrating large language models into recommendation via mu ... "
# WARNING Missing Expected Field 'journal' from entry yu2023product: " Product-matrix construction of ... "
# WARNING Missing Expected Field 'journal' from entry hou2023triple: " Triple-fault-tolerant binary m ... "
# WARNING Missing Expected Field 'journal' from entry li2023fast: " A Fast Algorithm for Finding t ... "
# WARNING Missing Expected Field 'journal' from entry wang2023matrix: " Matrix Completion via Coded Di ... "
# WARNING Missing Expected Field 'journal' from entry yan2024truncated: " Truncated Non-Uniform quantiza ... "
# SUCESSFULLY PARSED yan2024improved: " Improved Quantization Strategies for Managing Heavy-tailed G ... "
# WARNING Missing Expected Field 'journal' from entry huang2024mustard: " Mustard: Mastering uniform syn ... "
# WARNING Missing Expected Field 'journal' from entry li2024understanding: " Understanding and patching com ... "
# SUCESSFULLY PARSED chen2023gap: " Gap-closing matters: Perceptual quality evaluation and optim ... "
# WARNING Missing Expected Field 'journal' from entry luo2023framework: " A framework of large-scale pee ... "
# WARNING Missing Expected Field 'journal' from entry yao2024can: " Can LLM substitute human label ... "
# SUCESSFULLY PARSED cao2024competitive: " Competitive knowledge transfer--enhanced surrogate-assisted  ... "
# WARNING Missing Expected Field 'journal' from entry luo2024large: " Large language models augmente ... "
# SUCESSFULLY PARSED yao2024learning: " Learning from correctness without prompting makes LLM effici ... "
# SUCESSFULLY PARSED luo2024language: " A language model-based fine-grained address resolution frame ... "
# SUCESSFULLY PARSED ruan2024adaptive: " Adaptive top-k in SGD for communication-efficient distribute ... "
# WARNING Missing Expected Field 'journal' from entry zhong2024benchmarking: " Benchmarking and improving com ... "
# WARNING Missing Expected Field 'journal' from entry liu2024reed: " Reed-Solomon codes over cyclic ... "
# WARNING Missing Expected Field 'journal' from entry zhang2023semantic: " Semantic Communication Based o ... "
# SUCESSFULLY PARSED luo2024privacy: " Privacy in LLM-based recommendation: Recent advances and fut ... "
# WARNING Missing Expected Field 'journal' from entry liu2024bi: " Bi-chainer: automated large la ... "
# SUCESSFULLY PARSED liu2024towards: " Towards Improving Interpretability of Language Model Generat ... "
# WARNING Missing Expected Field 'journal' from entry luo2024recommender: " Recommender system and its ope ... "
# WARNING Missing Expected Field 'year' from entry yuxuan2023fine: " Fine-grained Conversational De ... "
# SUCESSFULLY PARSED zhu2024video: " Video quality assessment for spatio-temporal resolution adap ... "
# SUCESSFULLY PARSED lin2024fvel: " Fvel: Interactive formal verification environment with large ... "
# SUCESSFULLY PARSED jiang2024interpretable: " Interpretable catastrophic forgetting of large language mode ... "
# SUCESSFULLY PARSED yang2024scenario: " Scenario-adaptive key establishment scheme for lora-enabled  ... "
# WARNING Missing Expected Field 'journal' from entry sichun2024基於訓練和: " 基於訓練和/或操作圖神經網絡的推薦系統  "
# SUCESSFULLY PARSED yang2024benchmarking: " Benchmarking llms for optimization modeling and enhancing re ... "
# SUCESSFULLY PARSED qian2024octrack: " Octrack: benchmarking the open-corpus multi-object tracking  "
# SUCESSFULLY PARSED wu20243d: " 3d shape completion on unseen categories: A weakly-supervise ... "
# SUCESSFULLY PARSED su2024lightweight: " Lightweight instantly decodable network coding: Performance  ... "
# SUCESSFULLY PARSED lin2024rotation: " Rotation and permutation for advanced outlier management and ... "
# SUCESSFULLY PARSED jiang2025error: " Error correction decoding algorithms of RS codes based on an ... "
# WARNING Missing Expected Field 'journal' from entry xue2024multiobjective: " Multiobjective sequential tran ... "
# SUCESSFULLY PARSED xue2024surrogate: " Surrogate-assisted search with competitive knowledge transfe ... "
# WARNING Missing Expected Field 'journal' from entry wu2024multiobjective: " Multiobjective bayesian optimi ... "
# WARNING Missing Expected Field 'journal' from entry jiang2024tight: " Tight lower bound on cross-rac ... "
# WARNING Missing Expected Field 'journal' from entry zhu2024new: " New EVENODD+ Codes with More F ... "
# WARNING Missing Expected Field 'journal' from entry zhang2024rethinking: " Rethinking the one-shot object ... "
# WARNING Missing Expected Field 'journal' from entry hu2024heterogeneous: " Heterogeneous structured feder ... "
# WARNING Missing Expected Field 'journal' from entry wang2024lightweight: " Lightweight Instantly Decodabl ... "
# WARNING Missing Expected Field 'journal' from entry yao2025determine: " Determine-then-ensemble: Neces ... "
# WARNING Missing Expected Field 'journal' from entry wang2024mitigating: " Mitigating the language mismat ... "
# SUCESSFULLY PARSED lin2024duquant: " Duquant: Distributing outliers via dual transformation makes ... "
# SUCESSFULLY PARSED zhang2025short: " Short-sighted knowledge discovery in temporal transaction da ... "
# SUCESSFULLY PARSED qian2024vovtrack: " Vovtrack: Exploring the potentiality in videos for open-voca ... "
# WARNING Missing Expected Field 'journal' from entry yang2025optibench: " Optibench meets resocratic: Me ... "
# SUCESSFULLY PARSED zhang2024synthetic: " From Synthetic to Real: Unveiling the Power of Synthetic Dat ... "
# WARNING Missing Expected Field 'journal' from entry li2024loran: " Loran: Improved low-rank adapt ... "
# SUCESSFULLY PARSED zhang2026incremental: " Incremental Skyline Frequent-Utility Itemset Mining  "
# SUCESSFULLY PARSED xu2024cooperative: " Cooperative multi-model training for personalized federated  ... "
# SUCESSFULLY PARSED xu2024integrated: " Integrated object detection and communication for synthetic  ... "
# SUCESSFULLY PARSED yang2024iresnetdm: " iResNetDM: an interpretable deep learning approach for four  ... "
# WARNING Missing Expected Field 'journal' from entry ruan2024optimal: " Optimal power control for over ... "
# SUCESSFULLY PARSED zhang2025enabling: " Enabling knowledge discovery through low utility itemset min ... "
# WARNING Missing Expected Field 'journal' from entry luo2024training: " Training and operating neural  ... "
# WARNING Missing Expected Field 'journal' from entry yang2025mhmg: " mHMG-DTI: a drug-target intera ... "
# WARNING Missing Expected Field 'journal' from entry li2024new: " New Cauchy MDS array codes wit ... "
# WARNING Missing Expected Field 'journal' from entry yan2024towards: " Towards Quantum-Safe Distribut ... "
# WARNING Missing Expected Field 'journal' from entry liu2024cost: " On the I/O Cost of Linear Repa ... "
# WARNING Missing Expected Field 'journal' from entry wang2024addressing: " Addressing Fluctuating Straggl ... "
# WARNING Missing Expected Field 'journal' from entry shao2025diffetm: " Diffetm: Diffusion process enh ... "
# WARNING Missing Expected Field 'journal' from entry lin2024fast: " Fast Erasure Decoding of Reed- ... "
# WARNING Missing Expected Field 'journal' from entry li2024communication: " Communication-Efficient Multi- ... "
# SUCESSFULLY PARSED shi2025accelerating: " Accelerating Data Access for Single Node in Distributed Stor ... "
# SUCESSFULLY PARSED liu2025massive: " Massive Random Access Control for VLC: A Reinforcement Learn ... "
# WARNING Missing Expected Field 'journal' from entry xu2025rallrec: " Rallrec: Improving retrieval a ... "
# SUCESSFULLY PARSED zhou2025learning: " Learning and grounding visual multimodal adaptive graph for  ... "
# WARNING Missing Expected Field 'journal' from entry luo2025training: " Training and/or operating grap ... "
# SUCESSFULLY PARSED liu2025optishear: " Optishear: Towards efficient and adaptive pruning of large l ... "
# SUCESSFULLY PARSED liu20251bit: " 1bit-merging: Dynamic quantized merging for large language m ... "
# WARNING Missing Expected Field 'journal' from entry jiang2025unlocking: " Unlocking the Power of Functio ... "
# SUCESSFULLY PARSED ling2025communication: " Communication-Efficient and Privacy-Adaptable Mechanism for  ... "
# WARNING Missing Expected Field 'journal' from entry shuqi2025towards: " Towards Efficient Adaptation o ... "
# WARNING Missing Expected Field 'journal' from entry song2019minimizing: " Minimizing age of information  ... "
# SUCESSFULLY PARSED liu2025sens: " Sens-Merging: Sensitivity-Guided Parameter Balancing for Mer ... "
# SUCESSFULLY PARSED zhang2025skyline: " Skyline recency--frequency--monetary pattern mining based on ... "
# SUCESSFULLY PARSED luo2025rallrec+: " RALLRec+: Retrieval augmented large language model recommend ... "
# SUCESSFULLY PARSED wang2025subnetwork: " Subnetwork Knowledge Injection and Transferable Parameter Up ... "
# SUCESSFULLY PARSED luo2025reasoning: " Reasoning meets personalization: Unleashing the potential of ... "
# SUCESSFULLY PARSED zhang2025synthetic: " Synthetic-to-real video person re-id  "
# WARNING Missing Expected Field 'journal' from entry jiang2025makes: " What makes a good reasoning ch ... "
# SUCESSFULLY PARSED yao2026activation: " Activation-guided consensus merging for large language model ... "
# WARNING Missing Expected Field 'journal' from entry tan2024proxyqa: " {P}roxy{QA}: An Alternative Fr ... "
# WARNING Missing Expected Field 'journal' from entry lin2024mope: " Mope-clip: Structured pruning  ... "
# SUCESSFULLY PARSED song2014cemtekin: " CemTekin, and Mihaela van der Schaar, Fellow,“  "
# SUCESSFULLY PARSED liang2025low: " A low-complexity BP-OSD algorithm for quantum LDPC codes  "
# SUCESSFULLY PARSED liu2025reasoning: " Reasoning in Action: MCTS-Driven Knowledge Retrieval for Lar ... "
# WARNING Missing Expected Field 'year' from entry yao2403learning: " Learning from correctness with ... "
# SUCESSFULLY PARSED yao2025leveraging: " Leveraging Correctness-Based Learning for Efficient Reasonin ... "
# SUCESSFULLY PARSED xu2025multimodal: " Multimodal Named Entity Recognition based on topic prompt an ... "
# SUCESSFULLY PARSED yu2025explicit: " Explicit constructions of rack-aware regenerating codes for  ... "
# SUCESSFULLY PARSED liu2025beyond: " Beyond One-Size-Fits-All Pruning via Evolutionary Metric Sea ... "
# SUCESSFULLY PARSED yang2025drugmcts: " Drugmcts: a drug repurposing framework combining multi-agent ... "
# WARNING Missing Expected Field 'journal' from entry guanzhi2026hybrid: " Hybrid Llm-Knowledge Graph Sys ... "
# SUCESSFULLY PARSED deng2025klipa: " KLIPA: a knowledge graph and LLM-Driven QA framework for IP  ... "
# WARNING Missing Expected Field 'journal' from entry wang2025low: " Low-Complexity BP-ORBOSD Algor ... "
# SUCESSFULLY PARSED deng2025enhancing: " Enhancing Low-Rank Adaptation with Structured Nonlinear Tran ... "
# SUCESSFULLY PARSED li2025rema: " Rema: A unified reasoning manifold framework for interpretin ... "
# WARNING Missing Expected Field 'journal' from entry qian2025vovtrack: " VOVTrack: exploring the potent ... "
# WARNING Missing Expected Field 'year' from entry qianvovtrack: " VOVTrack: Exploring the Potent ... "
# SUCESSFULLY PARSED wang2025low2: " Low-complexity ordered statistic decoding algorithm based on ... "
# SUCESSFULLY PARSED wang2025two: " A two-stage soft-decision decoding algorithm for BCH codes  "
# SUCESSFULLY PARSED luo2026exploring: " Exploring the potential of large language models (LLMs) in a ... "
# SUCESSFULLY PARSED li2025client: " Client association and resource allocation for NOMA-enabled  ... "
# WARNING Missing Expected Field 'journal' from entry sichun2024用於訓練基於神經網絡的排序模型的計算機實現方法和系統: " 用於訓練基於神經網絡的排序模型的計算機實現方法和系統  "
# SUCESSFULLY PARSED liang2025belief: " Belief propagation-ordered statistics decoding algorithm wit ... "
# SUCESSFULLY PARSED liu2025dual: " Dual-perspective hypergraph learning network for multimodal  ... "
# SUCESSFULLY PARSED xu2025jmucod: " JMUCOD: joint maritime-underwater cross-domain object detect ... "
# SUCESSFULLY PARSED liu2026ucb: " A UCB Bandit Algorithm for General ML-Based Estimators  "
# SUCESSFULLY PARSED zhang2026dsa: " DSA-Tokenizer: Disentangled Semantic-Acoustic Tokenization v ... "
# SUCESSFULLY PARSED yang2026memo: " Memo-SQL: Structured Decomposition and Experience-Driven Sel ... "
# WARNING Missing Expected Field 'year' from entry wangunderstanding: " Understanding Before Evaluatio ... "
# WARNING Missing Expected Field 'journal' from entry wang2026temperature: " On Temperature-Constrained Non ... "
# SUCESSFULLY PARSED jiang2026cross: " Cross-Rack Update Bandwidth for Rack-Aware Storage Systems  "
# SUCESSFULLY PARSED wang2025bp: " BP-LCGCD: A Gaussian-elimination-free and high-performance d ... "
# SUCESSFULLY PARSED wang2025robust: " Robust Federated Learning under Heterogeneity via Rank-One a ... "
# SUCESSFULLY PARSED li2026scaling: " Scaling Reasoning Hop Exposes Weaknesses: Demystifying and I ... "
# SUCESSFULLY PARSED yao2026merging: " Merging Beyond: Streaming LLM Updates via Activation-Guided  ... "
# SUCESSFULLY PARSED wang2026multi: " Multi-Matrix Representative Ordered Statistics Decoding  "
# SUCESSFULLY PARSED liu2026efficient: " Efficient Encoding/Decoding Algorithms for Irreducible Polyn ... "
# WARNING Missing Expected Field 'year' from entry zeruiexpesql: " ExpeSQL: An Experience-Guided  ... "
# SUCESSFULLY PARSED xu2026self: " A self-modified hypergraph neural network for multimodal rel ... "
# WARNING Missing Expected Field 'journal' from entry zhou2025cross: " A Cross-Modal Information Retr ... "
# SUCESSFULLY PARSED shao2026towards: " Towards Privacy-Preserving Machine Translation At the Infere ... "
# WARNING Missing Expected Field 'journal' from entry wang2025reduced: " Reduced-complexity guessing co ... "
# SUCESSFULLY PARSED li2026role: " On the Role of Reasoning Patterns in the Generalization Disc ... "
# WARNING Missing Expected Field 'journal' from entry liu2026corrigendum: " Corrigendum to “Dual-perspecti ... "
# SUCESSFULLY PARSED cao2026systradebench: " SysTradeBench: An Iterative Build-Test-Patch Benchmark for S ... "
# SUCESSFULLY PARSED jian2026forge: " FORGE: Fine-grained multimodal evaluation for manufacturing  ... "
# SUCESSFULLY PARSED su2026grand: " On GRAND-Assisted Vector Random Linear Network Coding in Wir ... "
# WARNING Missing Expected Field 'journal' from entry wang2025maximum: " A maximum-likelihood decoding  ... "
# SUCESSFULLY PARSED li2026learning: " Learning to Reason with Insight for Informal Theorem Proving  "
# SUCESSFULLY PARSED fan2026parm: " PARM: Pipeline-Adapted Reward Model  "
# WARNING Missing Expected Field 'journal' from entry yang2026spatially: " Spatially-Coupled OTFS Systems ... "
# SUCESSFULLY PARSED tan2024flexible: " Flexible Coded Distributed Convolution Computing for Enhance ... "
# SUCESSFULLY PARSED liu2026dual: " Dual-perspective hypergraph learning network for multimodal  ... "
# SUCESSFULLY PARSED deng2026routing: " Routing-Aligned Fine-Tuning for Multilingual Downstream Task ... "
# SUCESSFULLY PARSED zhang2026speecheditbench: " SpeechEditBench: A Bilingual Multi-Attribute Benchmark for I ... "
# SUCESSFULLY PARSED liu2026long: " From Long News to Accurate Forecast: Importance-Aware Fusion ... "
# SUCESSFULLY PARSED wong2026automated: " Automated Proving of Shannon-Type Entropy Inequalities via F ... "
# SUCESSFULLY PARSED liu2026reasonalloc: " ReasonAlloc: Hierarchical Decoding-Time KV Cache Budget Allo ... "
# SUCESSFULLY PARSED liu2026power: " Power and Interference Management for VLC Ultra-Dense Networ ... "
# WARNING Missing Expected Field 'journal' from entry wang2026ge: " GE-Free BP-OSD for Short 5G LD ... "
# WARNING Missing Expected Field 'journal' from entry wu2026generalizing: " Generalizing the Outage Minimi ... "
# WARNING Missing Expected Field 'journal' from entry wang2026gaussian: " Gaussian Elimination-Free OSD  ... "
# WARNING Missing Expected Field 'journal' from entry wang2026resu: " Resu: A Regularized and Non-mo ... "
# SUCESSFULLY PARSED wu2026lavit: " Lavit: Aligning latent visual thoughts for multi-modal reaso ... "
# SUCESSFULLY PARSED zhang2026multimodal: " Multimodal emotion recognition via large model guided dialog ... "
# SUCESSFULLY PARSED zhang2026vl: " VL-DINO: Leveraging CLIP Vision-Language Knowledge for Open- ... "
# SUCESSFULLY PARSED shao2021pattern: " A pattern and POS auto-learning method for terminology extra ... "
# WARNING Missing Expected Field 'journal' from entry zerui2026memo: " Memo-SQL: Structured Decomposi ... "
# SUCESSFULLY PARSED li2026demopsd: " DemoPSD: Disagreement-Modulated Policy Self-Distillation  "
# SUCESSFULLY PARSED xu2026data: " Data augmentation with entity-object consistency for low-res ... "
# SUCESSFULLY PARSED wang2026gaussian2: " Gaussian-Elimination-Free Ordered Statistics Decoding via Pr ... "
# WARNING Missing Expected Field 'journal' from entry wang2026multiple: " Multiple-Cyclic-Basis GCD for  ... "
# SUCESSFULLY PARSED liu2026optical: " Optical Reflecting Intelligent Surface-Assisted Secure Visib ... "
# SUCESSFULLY PARSED wang2026partial: " Partial-Superposition HARQ for LDPC-Coded OTFS in Low-Altitu ... "
# SUCESSFULLY PARSED deng2026dr: " DR-LoRA: Dynamic Rank LoRA for Fine-Tuning Mixture-of-Expert ... "
# SUCESSFULLY PARSED wang2026gaussian3: " Gaussian-Elimination-Free BP-OSD Algorithm for Short 5G LDPC ... "
# SUCESSFULLY PARSED deng2026texas: " TEXAS: Task-Expert-Aware Supervision for Downstream Mixture- ... "
# SUCESSFULLY PARSED zhang2026speaker: " Speaker-Normalized Semantic Speech Tokens via Iterative S2U- ... "
